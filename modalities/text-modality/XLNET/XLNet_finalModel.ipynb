# %% [markdown]
# # XLNet

# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from sklearn.model_selection import train_test_split
from transformers import AutoModel, AutoTokenizer, AdamW
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from sklearn.utils.class_weight import compute_class_weight
from torch.optim.lr_scheduler import StepLR
import json
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Ensure GPU access

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

print(f'Using device: {device}')
# Out:
# Using device: cuda

# %% [markdown]
# # Load and preprocess the dataset

# %%
df = pd.read_csv("label_edited.csv",
                 sep='\t',
                 encoding='utf-8',
                 header=0)

df = df[['processed_text', 'mode', 'annotation_label']].dropna()

# %% [markdown]
# ## Label handling

# %% [markdown]
# ### Multilabel classification
#
# Here we handle multilabel classification split (Acc5, Acc7, ...), by mapping the labels from eg. for Acc3 `{-1, 0, 1}` -> `{0, 1, 2}` (because the model expects labels in this format)

# %%
# label_mapping = {-1: 0,
#                   0: 1,
#                   1: 2} # Map labels {-1, 0, 1} -> {0, 1, 2}

# df['annotation_label'] = df['annotation_label'].map(label_mapping).astype(int)

# %% [markdown]
# ### Binary classification

# %%
# df['annotation_label'] = df['annotation_label'].astype(float)

# %% [markdown]
# ## Subset Splitting

# %% [markdown]
# ### Our split
#
# Here we make the split by using a function
# - Splits into **train**, **validation** and **test** set (80%/10%/10%)

# %%
# train_text, testval_text, train_labels, testval_labels = train_test_split(df['processed_text'], df['annotation_label'],
#                                                                          random_state=42,
#                                                                          test_size=0.2,
#                                                                          stratify=df['annotation_label'])

# # Split the remaining 20% into 10% validation and 10% test sets
# val_text, test_text, val_labels, test_labels = train_test_split(testval_text, testval_labels,
#                                                                 random_state=42,
#                                                                 test_size=0.5,
#                                                                 stratify=testval_labels)

# %% [markdown]
# ### Dataset's split
#
# Here we use the dataset's preset split, in order to compare we other models

# %%
df['annotation_label'] = df['annotation_label'].astype(float)

# %%
train_text = df[df['mode'] == 'train']['processed_text']
train_labels = df[df['mode'] == 'train']['annotation_label']

val_text = df[df['mode'] == 'valid']['processed_text']
val_labels = df[df['mode'] == 'valid']['annotation_label']

test_text = df[df['mode'] == 'test']['processed_text']
test_labels = df[df['mode'] == 'test']['annotation_label']

# %% [markdown]
# #  Load pre-trained XLNet model and tokenizer
#
# We basically load the pre-trained XLNet model and tokenizer from the `transformers` library.
# Since we don't want to update the XLNet's weights, we use AutoModel and AutoTokenizer classes with the `from_pretrained` method to load the pre-trained model and tokenizer respectively (not the `forSequenceClassification` version of the model). We will just fine-tune the classifier head of the model.
# The classifier head is a single linear layer that takes the output of the last hidden layer of the XLNet model and maps it to the number of classes in the dataset.

# %%
xlnet = AutoModel.from_pretrained('xlnet-base-cased')
tokenizer = AutoTokenizer.from_pretrained('xlnet-base-cased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/760 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/467M [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/798k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.38M [00:00<?, ?B/s]

# %%
xlnet
# Out:
# XLNetModel(
#   (word_embedding): Embedding(32000, 768)
#   (layer): ModuleList(
#     (0-11): 12 x XLNetLayer(
#       (rel_attn): XLNetRelativeAttention(
#         (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ff): XLNetFeedForward(
#         (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#         (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (activation_function): GELUActivation()
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %% [markdown]
# ## Freeze XLNet
# In some cases, it might be interesting to keep the weights of the pre-trained encoder frozen and optimizing only the weights of the head layers.

# %%
# for param in roberta.parameters():
#     param.requires_grad = False

# %%
# for param in roberta.encoder.layer[11].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[10].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[9].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[8].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[7].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[6].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[5].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[4].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[3].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[2].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[1].parameters():
#     param.requires_grad = True

# for param in roberta.encoder.layer[0].parameters():
#     param.requires_grad = True

# for param in roberta.pooler.parameters():
#     param.requires_grad = True

# for param in roberta.embeddings.parameters():
#     param.requires_grad = True

# %%
for name, param in xlnet.named_parameters():
        if 'xlnet' or 'classifier' or 'pre_classifier' in name:
            print(f'{name}: {param.requires_grad}')
# Out:
# mask_emb: True
# word_embedding.weight: True
# layer.0.rel_attn.q: True
# layer.0.rel_attn.k: True
# layer.0.rel_attn.v: True
# layer.0.rel_attn.o: True
# layer.0.rel_attn.r: True
# layer.0.rel_attn.r_r_bias: True
# layer.0.rel_attn.r_s_bias: True
# layer.0.rel_attn.r_w_bias: True
# layer.0.rel_attn.seg_embed: True
# layer.0.rel_attn.layer_norm.weight: True
# layer.0.rel_attn.layer_norm.bias: True
# layer.0.ff.layer_norm.weight: True
# layer.0.ff.layer_norm.bias: True
# layer.0.ff.layer_1.weight: True
# layer.0.ff.layer_1.bias: True
# layer.0.ff.layer_2.weight: True
# layer.0.ff.layer_2.bias: True
# layer.1.rel_attn.q: True
# layer.1.rel_attn.k: True
# layer.1.rel_attn.v: True
# layer.1.rel_attn.o: True
# layer.1.rel_attn.r: True
# layer.1.rel_attn.r_r_bias: True
# layer.1.rel_attn.r_s_bias: True
# layer.1.rel_attn.r_w_bias: True
# layer.1.rel_attn.seg_embed: True
# layer.1.rel_attn.layer_norm.weight: True
# layer.1.rel_attn.layer_norm.bias: True
# layer.1.ff.layer_norm.weight: True
# layer.1.ff.layer_norm.bias: True
# layer.1.ff.layer_1.weight: True
# layer.1.ff.layer_1.bias: True
# layer.1.ff.layer_2.weight: True
# layer.1.ff.layer_2.bias: True
# layer.2.rel_attn.q: True
# layer.2.rel_attn.k: True
# layer.2.rel_attn.v: True
# layer.2.rel_attn.o: True
# layer.2.rel_attn.r: True
# layer.2.rel_attn.r_r_bias: True
# layer.2.rel_attn.r_s_bias: True
# layer.2.rel_attn.r_w_bias: True
# layer.2.rel_attn.seg_embed: True
# layer.2.rel_attn.layer_norm.weight: True
# layer.2.rel_attn.layer_norm.bias: True
# layer.2.ff.layer_norm.weight: True
# layer.2.ff.layer_norm.bias: True
# layer.2.ff.layer_1.weight: True
# layer.2.ff.layer_1.bias: True
# layer.2.ff.layer_2.weight: True
# layer.2.ff.layer_2.bias: True
# layer.3.rel_attn.q: True
# layer.3.rel_attn.k: True
# layer.3.rel_attn.v: True
# layer.3.rel_attn.o: True
# layer.3.rel_attn.r: True
# layer.3.rel_attn.r_r_bias: True
# layer.3.rel_attn.r_s_bias: True
# layer.3.rel_attn.r_w_bias: True
# layer.3.rel_attn.seg_embed: True
# layer.3.rel_attn.layer_norm.weight: True
# layer.3.rel_attn.layer_norm.bias: True
# layer.3.ff.layer_norm.weight: True
# layer.3.ff.layer_norm.bias: True
# layer.3.ff.layer_1.weight: True
# layer.3.ff.layer_1.bias: True
# layer.3.ff.layer_2.weight: True
# layer.3.ff.layer_2.bias: True
# layer.4.rel_attn.q: True
# layer.4.rel_attn.k: True
# layer.4.rel_attn.v: True
# layer.4.rel_attn.o: True
# layer.4.rel_attn.r: True
# layer.4.rel_attn.r_r_bias: True
# layer.4.rel_attn.r_s_bias: True
# layer.4.rel_attn.r_w_bias: True
# layer.4.rel_attn.seg_embed: True
# layer.4.rel_attn.layer_norm.weight: True
# layer.4.rel_attn.layer_norm.bias: True
# layer.4.ff.layer_norm.weight: True
# layer.4.ff.layer_norm.bias: True
# layer.4.ff.layer_1.weight: True
# layer.4.ff.layer_1.bias: True
# layer.4.ff.layer_2.weight: True
# layer.4.ff.layer_2.bias: True
# layer.5.rel_attn.q: True
# layer.5.rel_attn.k: True
# layer.5.rel_attn.v: True
# layer.5.rel_attn.o: True
# layer.5.rel_attn.r: True
# layer.5.rel_attn.r_r_bias: True
# layer.5.rel_attn.r_s_bias: True
# layer.5.rel_attn.r_w_bias: True
# layer.5.rel_attn.seg_embed: True
# layer.5.rel_attn.layer_norm.weight: True
# layer.5.rel_attn.layer_norm.bias: True
# layer.5.ff.layer_norm.weight: True
# layer.5.ff.layer_norm.bias: True
# layer.5.ff.layer_1.weight: True
# layer.5.ff.layer_1.bias: True
# layer.5.ff.layer_2.weight: True
# layer.5.ff.layer_2.bias: True
# layer.6.rel_attn.q: True
# layer.6.rel_attn.k: True
# layer.6.rel_attn.v: True
# layer.6.rel_attn.o: True
# layer.6.rel_attn.r: True
# layer.6.rel_attn.r_r_bias: True
# layer.6.rel_attn.r_s_bias: True
# layer.6.rel_attn.r_w_bias: True
# layer.6.rel_attn.seg_embed: True
# layer.6.rel_attn.layer_norm.weight: True
# layer.6.rel_attn.layer_norm.bias: True
# layer.6.ff.layer_norm.weight: True
# layer.6.ff.layer_norm.bias: True
# layer.6.ff.layer_1.weight: True
# layer.6.ff.layer_1.bias: True
# layer.6.ff.layer_2.weight: True
# layer.6.ff.layer_2.bias: True
# layer.7.rel_attn.q: True
# layer.7.rel_attn.k: True
# layer.7.rel_attn.v: True
# layer.7.rel_attn.o: True
# layer.7.rel_attn.r: True
# layer.7.rel_attn.r_r_bias: True
# layer.7.rel_attn.r_s_bias: True
# layer.7.rel_attn.r_w_bias: True
# layer.7.rel_attn.seg_embed: True
# layer.7.rel_attn.layer_norm.weight: True
# layer.7.rel_attn.layer_norm.bias: True
# layer.7.ff.layer_norm.weight: True
# layer.7.ff.layer_norm.bias: True
# layer.7.ff.layer_1.weight: True
# layer.7.ff.layer_1.bias: True
# layer.7.ff.layer_2.weight: True
# layer.7.ff.layer_2.bias: True
# layer.8.rel_attn.q: True
# layer.8.rel_attn.k: True
# layer.8.rel_attn.v: True
# layer.8.rel_attn.o: True
# layer.8.rel_attn.r: True
# layer.8.rel_attn.r_r_bias: True
# layer.8.rel_attn.r_s_bias: True
# layer.8.rel_attn.r_w_bias: True
# layer.8.rel_attn.seg_embed: True
# layer.8.rel_attn.layer_norm.weight: True
# layer.8.rel_attn.layer_norm.bias: True
# layer.8.ff.layer_norm.weight: True
# layer.8.ff.layer_norm.bias: True
# layer.8.ff.layer_1.weight: True
# layer.8.ff.layer_1.bias: True
# layer.8.ff.layer_2.weight: True
# layer.8.ff.layer_2.bias: True
# layer.9.rel_attn.q: True
# layer.9.rel_attn.k: True
# layer.9.rel_attn.v: True
# layer.9.rel_attn.o: True
# layer.9.rel_attn.r: True
# layer.9.rel_attn.r_r_bias: True
# layer.9.rel_attn.r_s_bias: True
# layer.9.rel_attn.r_w_bias: True
# layer.9.rel_attn.seg_embed: True
# layer.9.rel_attn.layer_norm.weight: True
# layer.9.rel_attn.layer_norm.bias: True
# layer.9.ff.layer_norm.weight: True
# layer.9.ff.layer_norm.bias: True
# layer.9.ff.layer_1.weight: True
# layer.9.ff.layer_1.bias: True
# layer.9.ff.layer_2.weight: True
# layer.9.ff.layer_2.bias: True
# layer.10.rel_attn.q: True
# layer.10.rel_attn.k: True
# layer.10.rel_attn.v: True
# layer.10.rel_attn.o: True
# layer.10.rel_attn.r: True
# layer.10.rel_attn.r_r_bias: True
# layer.10.rel_attn.r_s_bias: True
# layer.10.rel_attn.r_w_bias: True
# layer.10.rel_attn.seg_embed: True
# layer.10.rel_attn.layer_norm.weight: True
# layer.10.rel_attn.layer_norm.bias: True
# layer.10.ff.layer_norm.weight: True
# layer.10.ff.layer_norm.bias: True
# layer.10.ff.layer_1.weight: True
# layer.10.ff.layer_1.bias: True
# layer.10.ff.layer_2.weight: True
# layer.10.ff.layer_2.bias: True
# layer.11.rel_attn.q: True
# layer.11.rel_attn.k: True
# layer.11.rel_attn.v: True
# layer.11.rel_attn.o: True
# layer.11.rel_attn.r: True
# layer.11.rel_attn.r_r_bias: True
# layer.11.rel_attn.r_s_bias: True
# layer.11.rel_attn.r_w_bias: True
# layer.11.rel_attn.seg_embed: True
# layer.11.rel_attn.layer_norm.weight: True
# layer.11.rel_attn.layer_norm.bias: True
# layer.11.ff.layer_norm.weight: True
# layer.11.ff.layer_norm.bias: True
# layer.11.ff.layer_1.weight: True
# layer.11.ff.layer_1.bias: True
# layer.11.ff.layer_2.weight: True
# layer.11.ff.layer_2.bias: True

# %% [markdown]
# ## Tokenize and encode sequences

# %% [markdown]
# This is the maximum length of the input sequence expected by the model. If the length of the input sequence is greater than this, it will be truncated to this length. If the length of the input sequence is less than this, it will be padded to this length.
#
# - Due to lack of computational power & since BERT can only handle max 512 tokens.

# %%
df['processed_text'].str.len().max()
# Out:
# 575

# %%
df['processed_text'].str.len().mean()
# Out:
# 61.13460663938154

# %% [markdown]
# We chose close to the mean value

# %%
MAX_LEN = 128               # from {128, 256}

# %% [markdown]
# Here we tokenize and encode the sequences using the BERT tokenizer. We also truncate the sequences to the maximum length and pad them to the maximum length.

# %%
def tokenize_and_encode(texts):
    return tokenizer.batch_encode_plus(
        texts.tolist(),
        max_length=MAX_LEN,
        padding='max_length',
        truncation=True,
        return_token_type_ids=False
    )

# %%
tokens_train = tokenize_and_encode(train_text)
tokens_val = tokenize_and_encode(val_text)
tokens_test = tokenize_and_encode(test_text)

# %% [markdown]
# # Best hyperparameters found
# Here we load the best hyperparameters found during our grid search / tuning process using the `Aristotelis Cluster HPC`

# %%
epochs = 5

# %%
learning_rate = 1e-5            # The initial learning rate. The scheduler decreases it later...
weight_decay = 5e-4

# %%
hidden_size = 256               # from {32, 64, 128, 256}
batch_size = 16                  # from {8, 16, 32}
dropout_p = 0.1                 # from {0.1, 0.3}
activation_fn = 'No'          # from {ReLU, TanH, Identity}

# %% [markdown]
# ## Convert lists to tensors
#
# Here we convert the lists of `input_ids`, `attention_masks`, and `labels` to tensors so that they can be used as input to the model and to the Torch DataLoader.

# %%
def to_tensor(encoded_dict, labels):
    return (
        torch.tensor(encoded_dict['input_ids']),
        torch.tensor(encoded_dict['attention_mask']),
        torch.tensor(labels.tolist())
    )

# %%
train_seq, train_mask, train_y = to_tensor(tokens_train, train_labels)
val_seq, val_mask, val_y = to_tensor(tokens_val, val_labels)
test_seq, test_mask, test_y = to_tensor(tokens_test, test_labels)

# %%
test_seq.shape
# Out:
# torch.Size([686, 128])

# %%
test_y.shape
# Out:
# torch.Size([686])

# %% [markdown]
# ## Dataloaders

# %%
def create_data_loader(seq, mask, labels, sampler):
    data = TensorDataset(seq, mask, labels)
    return DataLoader(data, sampler=sampler(data), batch_size=batch_size)

# %%
train_dataloader = create_data_loader(train_seq, train_mask, train_y, RandomSampler)    # We use RandomSampler to to generate random indexes
                                                                                        # Basically, draw samples randomly from the train set
                                                                                        # for robustness and better generalization

val_dataloader = create_data_loader(val_seq, val_mask, val_y, SequentialSampler)        # Use SequentialSampler because we just evaluate
test_dataloader = create_data_loader(test_seq, test_mask, test_y, SequentialSampler)    # Use SequentialSampler because we just evaluate

# %% [markdown]
# # Model Architecture

# %%
class XLNET_Arch(nn.Module):
    def __init__(self, XLNET, dropout_p=0.1, hidden_size=768, activation_fn='No'):
        super(XLNET_Arch, self).__init__()
        # XLNET model
        self.XLNET = XLNET
        # Dropout layer
        self.dropout = nn.Dropout(dropout_p)
        # Activation Function
        if activation_fn == 'relu':
            self.actvfunc = nn.ReLU()
        elif activation_fn == 'tanh':
            self.actvfunc = nn.Tanh()
        elif activation_fn == 'No':
            self.actvfunc = nn.Identity()
        else:
            raise ValueError("Invalid activation function")
        # FC Layer
        self.fc = nn.Linear(768, hidden_size)   # ELECTRA outputs 768 by default
        # Output layer
        # MULTILABEL CLASSIFICATION
        # self.outp = nn.Linear(hidden_size, 3)    # Assuming 3 classes for classification
        # self.logsoftmax = nn.LogSoftmax(dim=1)
        # BINARY CLASSIFICATION
        self.outp = nn.Linear(hidden_size, 1)    # Assuming 2 classes for classification
        self.sigmoid = nn.Sigmoid()

    def forward(self, sent_id, mask):
        # ----------------------------------------------------------------
        # Pass inputs through BERT
        # We don't fine tune anything in BERT so we just pass the input
        # and take the pooled output (2nd item in tuple) and then pass it
        # through the fully connected layers
        outputs = self.XLNET(sent_id, attention_mask=mask)
        last_hidden_state = outputs[0]
        cls_hs = torch.mean(last_hidden_state, 1)
        # ----------------------------------------------------------------
        # Pass through fully connected layers
        # Hidden layer
        x = self.fc(cls_hs)    # Fully connected layer
        x = self.actvfunc(x)        # Activation function
        # Dropout
        x = self.dropout(x)
        # Output layer
        # MULTILABEL CLASSIFICATION
        # x = self.outp(x)
        # x = self.logsoftmax(x)    # Softmax function for multi-class classification
        # BINARY CLASSIFICATION
        x = self.outp(x)
        x = self.sigmoid(x)
        x = x.squeeze(-1)
        # ----------------------------------------------------------------

        return x

# %%
# Initialize the model and move it to GPU
model = XLNET_Arch(xlnet, dropout_p, hidden_size, activation_fn)
model = model.to(device)

# %% [markdown]
# ## Optimizer

# %%
# Define optimizer and class weights
optimizer = AdamW(model.parameters(),
                  lr=learning_rate,
                  weight_decay=weight_decay,
                  no_deprecation_warning=True)

# %% [markdown]
# ## Scheduler

# %%
# # Learning rate scheduler
# # Decays the learning rate of each parameter group by gamma every step_size epochs.
# scheduler = StepLR(optimizer,
#                    step_size=5,
#                    gamma=0.1) # for      epochs <  5: lr = 5e-4
#                               # for  5 < epochs < 10: lr = 5e-5
#                               # for 10 < epochs < 15: lr = 5e-6
#                               # We didn't try more frequent changes because we account for
#                               # computational efficiency - Small lr -> Slower convergance

# %% [markdown]
# ## Loss function
# We use the Cross Entropy Loss function as the loss function because this is a multi-class classification problem.

# %%
# Compute class weights and define loss function
# We compute the class weights to handle the class imbalance problem in the dataset
# so that we reduce the bias towards the majority class
class_wts = compute_class_weight(class_weight='balanced',
                                 classes=np.unique(train_labels),
                                 y=train_labels)

# %% [markdown]
# ### Multilabel classification
# We test both:
# - Negative Log Likelihood Loss function
# - Cross Entropy Loss
#
# for multilabel classification

# %%
# weights = torch.tensor(class_wts, dtype=torch.float).to(device)

# # loss_func = nn.CrossEntropyLoss(weight=weights)
# loss_func = nn.NLLLoss(weight=weights)              # from {NLLLoss, CrossEntropyLoss}
#                                                     # NLLLoss needs log-softmax output layer
#                                                     # CrossEntropyLoss needs softmax output layer

# %% [markdown]
# ### Binary classification
#
# We use Binary Cross Entropy Loss (with Logits Loss since we have a sigmoid output layer) for binary classification:

# %%
weights  = torch.tensor(class_wts[1], dtype=torch.float).to(device)  # Weight for positive class only
loss_func = nn.BCEWithLogitsLoss(pos_weight=weights)

# %% [markdown]
# ### Train function

# %%
def train(model, train_dataloader):
    # Set model to training mode
    model.train()

    total_loss = 0
    total_preds = []
    total_labels = []

    for step, batch in enumerate(train_dataloader):
        # Move batch to GPU (if it is the device we have)
        batch = [r.to(device) for r in batch]
        sent_id, mask, labels = batch

        # Clear previously calculated gradients
        model.zero_grad()

        # Get model predictions and compute loss
        preds = model(sent_id, mask)
        loss = loss_func(preds, labels)

        total_loss += loss.item()

        # Backward pass and gradient clipping
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update optimizer
        optimizer.step()

        # Collect predictions and labels
        preds = preds.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()

        # Store predictions and labels to calculate accuracy after all batches are processed
        total_preds.append(preds)
        total_labels.append(labels)

    # Concatenate accumulated predictions and labels
    total_preds = np.concatenate(total_preds, axis=0)
    total_labels = np.concatenate(total_labels, axis=0)

    # Convert predictions to binary labels for accuracy calculation
    train_labels = (total_preds >= 0.5).astype(int)
    train_accuracy = np.mean(train_labels == total_labels)

    avg_loss = total_loss / len(train_dataloader)
    return avg_loss, train_accuracy, total_preds

# %% [markdown]
# ### Evaluation function

# %%
def evaluate(model, val_dataloader):
    # Set model to evaluation mode
    model.eval()

    total_loss = 0
    total_preds = []
    for step, batch in enumerate(val_dataloader):
        # Move batch to GPU
        batch = [r.to(device) for r in batch]
        sent_id, mask, labels = batch

        # Deactivate autograd and compute predictions
        # We deactivate autograd because we don't want to update the model's weights
        with torch.no_grad():
            preds = model(sent_id, mask)
            loss = loss_func(preds, labels)
            total_loss += loss.item()

            # Calculate predictions and move to CPU to detach from computational graph
            preds = preds.detach().cpu().numpy()
            total_preds.append(preds)

    avg_loss = total_loss / len(val_dataloader)
    total_preds = np.concatenate(total_preds, axis=0)
    return avg_loss, total_preds

# %% [markdown]
# # Training loop

# %%
train_losses, valid_losses = [], []
best_valid_loss = float('inf')
best_valid_loss_epoch = 0

for epoch in range(epochs):
    print(f'\n Epoch {epoch + 1} / {epochs}')

    # Train the model
    train_loss, _, _ = train(model, train_dataloader)
    train_losses.append(train_loss)

    # Evaluate the model on the validation set
    valid_loss, _ = evaluate(model, val_dataloader)
    valid_losses.append(valid_loss)

    # Step the scheduler
    # scheduler.step()

    print(f'Training Loss: {train_loss:.3f}')
    print(f'Validation Loss: {valid_loss:.3f}')

    # Save the model if it has the best validation loss so far
    if valid_loss <= best_valid_loss:   # If we find one with the same, keep the one with the biggest epoch
        best_valid_loss = valid_loss
        best_valid_loss_epoch = epoch + 1
        torch.save(model.state_dict(), 'XLNet_best_model_state.bin')
# Out:
#  Epoch 1 / 5
# Training Loss: 0.635
# Validation Loss: 0.596
#
#  Epoch 2 / 5
# Training Loss: 0.566
# Validation Loss: 0.538
#
#  Epoch 3 / 5
# Training Loss: 0.534
# Validation Loss: 0.521
#
#  Epoch 4 / 5
# Training Loss: 0.527
# Validation Loss: 0.521
#
#  Epoch 5 / 5
# Training Loss: 0.514
# Validation Loss: 0.520

# %% [markdown]
# ### Optimal Epochs

# %%
print("Optimal epoch: ", best_valid_loss_epoch)
# Out:
# Optimal epoch:  5

# %% [markdown]
# ## Learning Curve

# %%
# Plot the learning curve
plt.plot(range(1, epochs+1), train_losses,
         label='Training Loss')
plt.plot(range(1, epochs+1), valid_losses,
         label='Validation Loss')
plt.xticks(range(1, epochs+1))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Learning Curve')
plt.legend()
plt.show()

# %% [markdown]
# # Load the optimal epoch model

# %%
# Initialize a model and move it to GPU
model_opt = XLNET_Arch(xlnet, dropout_p, hidden_size, activation_fn)
model_opt = model.to(device)

# Load
model_opt.load_state_dict(torch.load('XLNet_best_model_state.bin'))      # Load the saved state dictionary
model_opt.eval()                                                         # Set the model to evaluation mode
# Out:
# <ipython-input-141-e43fc958a067>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_opt.load_state_dict(torch.load('XLNet_best_model_state.bin'))      # Load the saved state dictionary
# XLNET_Arch(
#   (XLNET): XLNetModel(
#     (word_embedding): Embedding(32000, 768)
#     (layer): ModuleList(
#       (0-11): 12 x XLNetLayer(
#         (rel_attn): XLNetRelativeAttention(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ff): XLNetFeedForward(
#           (layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layer_1): Linear(in_features=768, out_features=3072, bias=True)
#           (layer_2): Linear(in_features=3072, out_features=768, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#           (activation_function): GELUActivation()
#         )
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (actvfunc): Identity()
#   (fc): Linear(in_features=768, out_features=256, bias=True)
#   (outp): Linear(in_features=256, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )

# %% [markdown]
# ## Metrics

# %%
# Assuming you have already created test_dataloader
avg_loss, test_preds = evaluate(model_opt, test_dataloader)

# Print the results
print(f'Average Loss: {avg_loss:.4f}')
# Out:
# Average Loss: 0.5864

# %% [markdown]
# ### Multilabel Classification

# %%
# inverted_mapping = {v: k for k, v in label_mapping.items()}

# predicted_labels = np.argmax(test_preds, axis=1)

# # Mapping using the inverted mapping
# # from {0, 1, 2} back to the original labeling {-1, 0, 1}
# predicted_labels_unmapped = np.array(list(map(lambda x: inverted_mapping[x], predicted_labels)))
# test_y_unmapped = np.array(list(map(lambda x: inverted_mapping[x], test_y.numpy())))

# %%
# # Print the classification report
# print(classification_report(test_y_unmapped, predicted_labels_unmapped, digits=4))

# %% [markdown]
# ### Binary Classification

# %%
predicted_labels = (test_preds >= 0.5)

# %%
# Print the classification report
print(classification_report(test_y, predicted_labels, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.8488    0.8443    0.8466       379
#          1.0     0.8091    0.8143    0.8117       307
#
#     accuracy                         0.8309       686
#    macro avg     0.8289    0.8293    0.8291       686
# weighted avg     0.8310    0.8309    0.8310       686

# %%
confusion_matrix = pd.crosstab(test_y, predicted_labels)

# %%
# Set the size of the figure
plt.figure(figsize=(10, 7))

# Create a heatmap from the confusion matrix
sns.heatmap(confusion_matrix,
            annot=True,
            fmt='d',
            cmap='Blues',
            cbar=True)

# Set titles and labels
plt.title('Fine-Tuned XLNet (Optimal Parameters) Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')

# Show the plot
plt.show()
